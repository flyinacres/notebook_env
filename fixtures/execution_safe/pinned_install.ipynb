# %%
# Cell 1: Explicit pip install of pure-python library
# %pip install humanize==4.10.0

# %%
# Cell 2: Import and functional smoke test
import humanize
import importlib.metadata

# 1. Verify metadata
dist_ver = importlib.metadata.version('humanize')
assert dist_ver == '4.10.0', f'Expected 4.10.0, got {dist_ver}'

# 2. Functional API verification
formatted = humanize.naturalsize(1024)
assert formatted == '1.0 kB', f'Expected 1.0 kB, got {formatted}'
print('Pinned install verification passed: humanize 4.10.0 active')
