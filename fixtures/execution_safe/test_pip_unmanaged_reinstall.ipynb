# %%
# Unmanaged pip cell: forces a real downgrade/reinstall (not covered by notebook_env's own managed setup)
# %pip install humanize==4.10.0

# %%
import humanize
import importlib.metadata
dist_ver = importlib.metadata.version('humanize')
assert dist_ver is not None and len(dist_ver) > 0, 'humanize version metadata not found'
formatted = humanize.naturalsize(1024)
assert formatted == '1.0 kB', f'Expected 1.0 kB, got {formatted}'
print(f'Unmanaged pip reinstall verification passed: humanize {dist_ver} active')
